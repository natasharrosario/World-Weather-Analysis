# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | chingola
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lasa
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | alyangula
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | yeppoon
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | kutum
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | half moon bay
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | tondon
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | kasongo-lunda
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | lidkoping
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | burica
# City not found. Skipping...
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | rumonge
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | agutaya
# Processing Record 41 of Set 1 | pritzwalk
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | opuwo
# Processing Record 46 of Set 1 | slave lake
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | thunder bay
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | qaqortoq
# Processing Record 6 of Set 2 | togur
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | aykhal
# Processing Record 11 of Set 2 | derac
# Processing Record 12 of Set 2 | bima
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | bela
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | cayenne
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | banjar
# Processing Record 22 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | kawalu
# Processing Record 25 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 26 of Set 2 | santarem
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | jiuquan
# Processing Record 32 of Set 2 | nadym
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | aborlan
# Processing Record 35 of Set 2 | fairbanks
# Processing Record 36 of Set 2 | crossville
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | dolores
# Processing Record 41 of Set 2 | kinablangan
# Processing Record 42 of Set 2 | sonoita
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | kamaishi
# Processing Record 46 of Set 2 | elizabeth city
# Processing Record 47 of Set 2 | acuna
# City not found. Skipping...
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | weiser
# Processing Record 1 of Set 3 | diu
# Processing Record 2 of Set 3 | charters towers
# Processing Record 3 of Set 3 | pandamatenga
# Processing Record 4 of Set 3 | puerto el triunfo
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | guara
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | orocue
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | bambanglipuro
# Processing Record 13 of Set 3 | trelew
# Processing Record 14 of Set 3 | general pico
# Processing Record 15 of Set 3 | marystown
# Processing Record 16 of Set 3 | taltal
# Processing Record 17 of Set 3 | kichera
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | goulburn
# Processing Record 20 of Set 3 | murud
# Processing Record 21 of Set 3 | sorland
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | sepolno krajenskie
# Processing Record 24 of Set 3 | la ronge
# Processing Record 25 of Set 3 | havre-saint-pierre
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | oussouye
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | bosaso
# Processing Record 30 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | san jose
# Processing Record 33 of Set 3 | berdigestyakh
# Processing Record 34 of Set 3 | lagoa
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | luena
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | darnah
# Processing Record 39 of Set 3 | katherine
# Processing Record 40 of Set 3 | sacramento
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | teknaf
# Processing Record 43 of Set 3 | nagato
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | saint-leu
# Processing Record 48 of Set 3 | ampanihy
# Processing Record 49 of Set 3 | contamana
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | kangaatsiaq
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | ormara
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | buenos aires
# Processing Record 9 of Set 4 | henties bay
# Processing Record 10 of Set 4 | ust-maya
# Processing Record 11 of Set 4 | bonthe
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | safranbolu
# Processing Record 14 of Set 4 | mizdah
# Processing Record 15 of Set 4 | sola
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | sao francisco de paula
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | lakes entrance
# Processing Record 23 of Set 4 | conakry
# Processing Record 24 of Set 4 | antofagasta
# Processing Record 25 of Set 4 | nynashamn
# Processing Record 26 of Set 4 | kaeo
# Processing Record 27 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 4 | minggang
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 4 | gat
# Processing Record 32 of Set 4 | puerto leguizamo
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | nabire
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | libreville
# Processing Record 37 of Set 4 | walvis bay
# Processing Record 38 of Set 4 | lalmohan
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | nampula
# Processing Record 41 of Set 4 | san policarpo
# Processing Record 42 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 4 | verkhnyaya sinyachikha
# Processing Record 44 of Set 4 | verkhovazhye
# Processing Record 45 of Set 4 | buala
# Processing Record 46 of Set 4 | kirakira
# Processing Record 47 of Set 4 | rawson
# Processing Record 48 of Set 4 | san jeronimo
# Processing Record 49 of Set 4 | kampong thum
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 5 | huarmey
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | oia
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 5 | erzurum
# Processing Record 7 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 5 | gainesville
# Processing Record 9 of Set 5 | andra
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | shubarkuduk
# Processing Record 13 of Set 5 | itaituba
# Processing Record 14 of Set 5 | tasiilaq
# Processing Record 15 of Set 5 | komagane
# Processing Record 16 of Set 5 | omsukchan
# Processing Record 17 of Set 5 | kedgwick
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | alta floresta
# Processing Record 20 of Set 5 | vila franca do campo
# Processing Record 21 of Set 5 | vangaindrano
# Processing Record 22 of Set 5 | kharp
# Processing Record 23 of Set 5 | kununurra
# Processing Record 24 of Set 5 | zhangjiakou
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | chikwawa
# Processing Record 27 of Set 5 | atherton
# Processing Record 28 of Set 5 | cortez
# Processing Record 29 of Set 5 | toamasina
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | natal
# Processing Record 32 of Set 5 | kaniama
# Processing Record 33 of Set 5 | port hawkesbury
# Processing Record 34 of Set 5 | san quintin
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | rocha
# Processing Record 38 of Set 5 | ewa beach
# Processing Record 39 of Set 5 | port macquarie
# Processing Record 40 of Set 5 | makakilo city
# Processing Record 41 of Set 5 | saskylakh
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | chifeng
# Processing Record 44 of Set 5 | george
# Processing Record 45 of Set 5 | pochutla
# Processing Record 46 of Set 5 | dezhou
# Processing Record 47 of Set 5 | jacareacanga
# Processing Record 48 of Set 5 | port blair
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | pierre
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | paita
# Processing Record 4 of Set 6 | santiago del estero
# Processing Record 5 of Set 6 | idah
# Processing Record 6 of Set 6 | bowen
# Processing Record 7 of Set 6 | whitehorse
# Processing Record 8 of Set 6 | vila velha
# Processing Record 9 of Set 6 | sai buri
# Processing Record 10 of Set 6 | pevek
# Processing Record 11 of Set 6 | luoyang
# Processing Record 12 of Set 6 | bayan
# Processing Record 13 of Set 6 | port alfred
# Processing Record 14 of Set 6 | belle fourche
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | hervey bay
# Processing Record 17 of Set 6 | teya
# Processing Record 18 of Set 6 | ozernovskiy
# Processing Record 19 of Set 6 | pathein
# Processing Record 20 of Set 6 | chicama
# Processing Record 21 of Set 6 | swan river
# Processing Record 22 of Set 6 | yarada
# Processing Record 23 of Set 6 | carutapera
# Processing Record 24 of Set 6 | tarija
# Processing Record 25 of Set 6 | axim
# Processing Record 26 of Set 6 | liangxiang
# Processing Record 27 of Set 6 | kamennogorsk
# Processing Record 28 of Set 6 | koulamoutou
# Processing Record 29 of Set 6 | san carlos de bariloche
# Processing Record 30 of Set 6 | mogadishu
# Processing Record 31 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 32 of Set 6 | kaoma
# Processing Record 33 of Set 6 | inirida
# Processing Record 34 of Set 6 | dharchula
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | novosil
# Processing Record 37 of Set 6 | miyang
# Processing Record 38 of Set 6 | santa rosa
# Processing Record 39 of Set 6 | tanza
# Processing Record 40 of Set 6 | esperance
# Processing Record 41 of Set 6 | quelimane
# Processing Record 42 of Set 6 | altus
# Processing Record 43 of Set 6 | santa marta
# Processing Record 44 of Set 6 | itarema
# Processing Record 45 of Set 6 | boda
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | buin
# Processing Record 48 of Set 6 | lashio
# Processing Record 49 of Set 6 | paso de carrasco
# Processing Record 50 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 7 | arlit
# Processing Record 2 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 7 | nantucket
# Processing Record 4 of Set 7 | sambava
# Processing Record 5 of Set 7 | salalah
# Processing Record 6 of Set 7 | tura
# Processing Record 7 of Set 7 | baykit
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 10 of Set 7 | zalegoshch
# Processing Record 11 of Set 7 | iwanai
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | fort saint james
# Processing Record 14 of Set 7 | yenangyaung
# Processing Record 15 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 7 | kaputa
# Processing Record 17 of Set 7 | okha
# Processing Record 18 of Set 7 | ambon
# Processing Record 19 of Set 7 | yoichi
# Processing Record 20 of Set 7 | gent
# Processing Record 21 of Set 7 | juba
# Processing Record 22 of Set 7 | ayan
# Processing Record 23 of Set 7 | saint george
# Processing Record 24 of Set 7 | puerto ayacucho
# Processing Record 25 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 7 | mubi
# Processing Record 27 of Set 7 | camacha
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 7 | horodyshche
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | lakselv
# Processing Record 33 of Set 7 | bubaque
# Processing Record 34 of Set 7 | santa vitoria do palmar
# Processing Record 35 of Set 7 | cerro punta
# Processing Record 36 of Set 7 | meadow lake
# Processing Record 37 of Set 7 | katsuura
# Processing Record 38 of Set 7 | terrace bay
# Processing Record 39 of Set 7 | dauphin
# Processing Record 40 of Set 7 | shahpur
# Processing Record 41 of Set 7 | narasannapeta
# Processing Record 42 of Set 7 | nouakchott
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | victor harbor
# Processing Record 46 of Set 7 | kisangani
# Processing Record 47 of Set 7 | brumunddal
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | chulman
# Processing Record 50 of Set 7 | azogues
# Processing Record 1 of Set 8 | stornoway
# Processing Record 2 of Set 8 | vallenar
# Processing Record 3 of Set 8 | challapata
# Processing Record 4 of Set 8 | marovoay
# Processing Record 5 of Set 8 | hohhot
# Processing Record 6 of Set 8 | rizhao
# Processing Record 7 of Set 8 | honiara
# Processing Record 8 of Set 8 | parana
# Processing Record 9 of Set 8 | sao filipe
# Processing Record 10 of Set 8 | kostomuksha
# Processing Record 11 of Set 8 | bom jesus
# Processing Record 12 of Set 8 | pozo colorado
# Processing Record 13 of Set 8 | deputatskiy
# Processing Record 14 of Set 8 | srednekolymsk
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | tevaitoa
# Processing Record 17 of Set 8 | lufilufi
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | acapulco
# Processing Record 20 of Set 8 | praia
# Processing Record 21 of Set 8 | olafsvik
# Processing Record 22 of Set 8 | the valley
# Processing Record 23 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 24 of Set 8 | inhambane
# Processing Record 25 of Set 8 | timizart
# Processing Record 26 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 8 | berlevag
# Processing Record 28 of Set 8 | bandarbeyla
# Processing Record 29 of Set 8 | zyryanka
# Processing Record 30 of Set 8 | porto franco
# Processing Record 31 of Set 8 | sorong
# Processing Record 32 of Set 8 | kiama
# Processing Record 33 of Set 8 | kamareddi
# Processing Record 34 of Set 8 | taybad
# Processing Record 35 of Set 8 | monze
# Processing Record 36 of Set 8 | shache
# Processing Record 37 of Set 8 | alugan
# Processing Record 38 of Set 8 | saint-louis
# Processing Record 39 of Set 8 | sheridan
# Processing Record 40 of Set 8 | poros
# Processing Record 41 of Set 8 | yabrud
# Processing Record 42 of Set 8 | nancha
# Processing Record 43 of Set 8 | iquique
# Processing Record 44 of Set 8 | kortkeros
# Processing Record 45 of Set 8 | garowe
# Processing Record 46 of Set 8 | plettenberg bay
# Processing Record 47 of Set 8 | novobirilyussy
# Processing Record 48 of Set 8 | banda aceh
# Processing Record 49 of Set 8 | minab
# Processing Record 50 of Set 8 | hajnowka
# Processing Record 1 of Set 9 | buldana
# Processing Record 2 of Set 9 | beira
# Processing Record 3 of Set 9 | umm kaddadah
# Processing Record 4 of Set 9 | carnduff
# Processing Record 5 of Set 9 | bodden town
# Processing Record 6 of Set 9 | kavant
# City not found. Skipping...
# Processing Record 7 of Set 9 | sioux lookout
# Processing Record 8 of Set 9 | kavaratti
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | simbahan
# Processing Record 11 of Set 9 | bereda
# Processing Record 12 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 9 | madimba
# Processing Record 14 of Set 9 | brae
# Processing Record 15 of Set 9 | kyabe
# Processing Record 16 of Set 9 | solnechnyy
# Processing Record 17 of Set 9 | sarkikaraagac
# Processing Record 18 of Set 9 | jalu
# Processing Record 19 of Set 9 | canto do buriti
# Processing Record 20 of Set 9 | japura
# Processing Record 21 of Set 9 | grenville
# Processing Record 22 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 9 | gresham
# Processing Record 24 of Set 9 | sistranda
# Processing Record 25 of Set 9 | sumenep
# Processing Record 26 of Set 9 | stamsund
# City not found. Skipping...
# Processing Record 27 of Set 9 | reinosa
# Processing Record 28 of Set 9 | bathsheba
# Processing Record 29 of Set 9 | porosozero
# Processing Record 30 of Set 9 | ketchikan
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | dukat
# Processing Record 33 of Set 9 | longyearbyen
# Processing Record 34 of Set 9 | nicoya
# Processing Record 35 of Set 9 | caldwell
# Processing Record 36 of Set 9 | garzon
# Processing Record 37 of Set 9 | isparta
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | talakan
# Processing Record 40 of Set 9 | naze
# Processing Record 41 of Set 9 | beloha
# Processing Record 42 of Set 9 | beipiao
# Processing Record 43 of Set 9 | tomatlan
# Processing Record 44 of Set 9 | pong
# Processing Record 45 of Set 9 | chortomlyk
# Processing Record 46 of Set 9 | pitimbu
# Processing Record 47 of Set 9 | dakar
# Processing Record 48 of Set 9 | namtsy
# Processing Record 49 of Set 9 | abu zabad
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | touros
# Processing Record 2 of Set 10 | methoni
# Processing Record 3 of Set 10 | gorontalo
# Processing Record 4 of Set 10 | valdosta
# Processing Record 5 of Set 10 | bilma
# Processing Record 6 of Set 10 | bollnas
# Processing Record 7 of Set 10 | smithers
# Processing Record 8 of Set 10 | bocas del toro
# Processing Record 9 of Set 10 | diapaga
# Processing Record 10 of Set 10 | nishihara
# Processing Record 11 of Set 10 | gushikawa
# Processing Record 12 of Set 10 | oktyabrskoye
# Processing Record 13 of Set 10 | kharitonovo
# Processing Record 14 of Set 10 | zhigansk
# Processing Record 15 of Set 10 | rochegda
# Processing Record 16 of Set 10 | north bend
# Processing Record 17 of Set 10 | lamu
# Processing Record 18 of Set 10 | saint-pierre
# Processing Record 19 of Set 10 | mikhaylovka
# Processing Record 20 of Set 10 | tazmalt
# Processing Record 21 of Set 10 | kaka
# Processing Record 22 of Set 10 | pangody
# Processing Record 23 of Set 10 | jiwani
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 10 | vostok
# Processing Record 27 of Set 10 | koumac
# Processing Record 28 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 10 | kupang
# Processing Record 30 of Set 10 | ust-tsilma
# Processing Record 31 of Set 10 | mgandu
# Processing Record 32 of Set 10 | norman wells
# Processing Record 33 of Set 10 | gambela
# Processing Record 34 of Set 10 | hasaki
# Processing Record 35 of Set 10 | esmeraldas
# Processing Record 36 of Set 10 | mount vernon
# Processing Record 37 of Set 10 | tambura
# Processing Record 38 of Set 10 | ulaangom
# Processing Record 39 of Set 10 | dunedin
# Processing Record 40 of Set 10 | sao miguel do araguaia
# Processing Record 41 of Set 10 | kilmez
# City not found. Skipping...
# Processing Record 42 of Set 10 | krasnaya gorka
# Processing Record 43 of Set 10 | quarai
# Processing Record 44 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 45 of Set 10 | biloela
# Processing Record 46 of Set 10 | okhotsk
# Processing Record 47 of Set 10 | guaruja
# Processing Record 48 of Set 10 | ucluelet
# Processing Record 49 of Set 10 | brockville
# Processing Record 50 of Set 10 | shimoda
# Processing Record 1 of Set 11 | petatlan
# Processing Record 2 of Set 11 | kolosovka
# Processing Record 3 of Set 11 | bonnyville
# Processing Record 4 of Set 11 | severnoye
# Processing Record 5 of Set 11 | talara
# Processing Record 6 of Set 11 | shirokiy
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | marshfield
# Processing Record 9 of Set 11 | shitanjing
# Processing Record 10 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 11 | catuday
# Processing Record 12 of Set 11 | biu
# Processing Record 13 of Set 11 | sterling
# Processing Record 14 of Set 11 | aguimes
# Processing Record 15 of Set 11 | macenta
# Processing Record 16 of Set 11 | port ellen
# City not found. Skipping...
# Processing Record 17 of Set 11 | san rafael
# Processing Record 18 of Set 11 | avera
# Processing Record 19 of Set 11 | aripuana
# Processing Record 20 of Set 11 | sibolga
# Processing Record 21 of Set 11 | darhan
# Processing Record 22 of Set 11 | maceio
# Processing Record 23 of Set 11 | baie-saint-paul
# Processing Record 24 of Set 11 | guerrero negro
# Processing Record 25 of Set 11 | praia da vitoria
# Processing Record 26 of Set 11 | basco
# Processing Record 27 of Set 11 | ixtapa
# Processing Record 28 of Set 11 | muzhi
# Processing Record 29 of Set 11 | qui nhon
# Processing Record 30 of Set 11 | chuy
# Processing Record 31 of Set 11 | haverfordwest
# Processing Record 32 of Set 11 | muros
# Processing Record 33 of Set 11 | madisonville
# Processing Record 34 of Set 11 | sobolevo
# Processing Record 35 of Set 11 | beba
# Processing Record 36 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 11 | selma
# Processing Record 38 of Set 11 | borba
# Processing Record 39 of Set 11 | deer lake
# Processing Record 40 of Set 11 | parrita
# Processing Record 41 of Set 11 | mount gambier
# Processing Record 42 of Set 11 | batagay
# Processing Record 43 of Set 11 | mpika
# Processing Record 44 of Set 11 | dwarka
# Processing Record 45 of Set 11 | abha
# Processing Record 46 of Set 11 | beringovskiy
# Processing Record 47 of Set 11 | lorengau
# Processing Record 48 of Set 11 | tilichiki
# Processing Record 49 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 11 | riacho de santana
# Processing Record 1 of Set 12 | nobeoka
# Processing Record 2 of Set 12 | gravdal
# Processing Record 3 of Set 12 | liberal
# Processing Record 4 of Set 12 | kibala
# Processing Record 5 of Set 12 | baruun-urt
# Processing Record 6 of Set 12 | villamontes
# Processing Record 7 of Set 12 | clyde river
# Processing Record 8 of Set 12 | nipawin
# Processing Record 9 of Set 12 | aleksandrovskoye
# Processing Record 10 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 12 | pangkalanbuun
# Processing Record 12 of Set 12 | abbeville
# Processing Record 13 of Set 12 | enid
# Processing Record 14 of Set 12 | rakai
# Processing Record 15 of Set 12 | kalamare
# Processing Record 16 of Set 12 | sinnamary
# Processing Record 17 of Set 12 | harper
# Processing Record 18 of Set 12 | byron bay
# Processing Record 19 of Set 12 | faya
# Processing Record 20 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 12 | rio gallegos
# Processing Record 22 of Set 12 | tshikapa
# Processing Record 23 of Set 12 | aiquile
# Processing Record 24 of Set 12 | nouadhibou
# Processing Record 25 of Set 12 | dortyol
# Processing Record 26 of Set 12 | kanniyakumari
# Processing Record 27 of Set 12 | luau
# Processing Record 28 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 12 | hanzhong
# Processing Record 30 of Set 12 | troy
# Processing Record 31 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 12 | lata
# Processing Record 34 of Set 12 | alpena
# Processing Record 35 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 12 | volchansk
# Processing Record 38 of Set 12 | malatya
# Processing Record 39 of Set 12 | tazovskiy
# Processing Record 40 of Set 12 | leningradskiy
# Processing Record 41 of Set 12 | kyzyl-suu
# Processing Record 42 of Set 12 | dingle
# Processing Record 43 of Set 12 | russell
# Processing Record 44 of Set 12 | port-gentil
# Processing Record 45 of Set 12 | tukrah
# Processing Record 46 of Set 12 | road town
# Processing Record 47 of Set 12 | abnub
# Processing Record 48 of Set 12 | aklavik
# Processing Record 49 of Set 12 | kruisfontein
# Processing Record 50 of Set 12 | de-kastri
# Processing Record 1 of Set 13 | aleksandrov gay
# Processing Record 2 of Set 13 | flores
# Processing Record 3 of Set 13 | xixiang
# Processing Record 4 of Set 13 | horsham
# Processing Record 5 of Set 13 | castrillon
# Processing Record 6 of Set 13 | veraval
# Processing Record 7 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 13 | santiago
# Processing Record 9 of Set 13 | miri
# Processing Record 10 of Set 13 | honningsvag
# Processing Record 11 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | rawah
# Processing Record 13 of Set 13 | bergen
# Processing Record 14 of Set 13 | santa cruz de la palma
# Processing Record 15 of Set 13 | berlin
# Processing Record 16 of Set 13 | asau
# Processing Record 17 of Set 13 | ajdabiya
# Processing Record 18 of Set 13 | masyaf
# Processing Record 19 of Set 13 | yiyang
# Processing Record 20 of Set 13 | prince george
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | graham
# Processing Record 23 of Set 13 | kalabo
# Processing Record 24 of Set 13 | anloga
# Processing Record 25 of Set 13 | vanimo
# Processing Record 26 of Set 13 | lavrentiya
# Processing Record 27 of Set 13 | kasempa
# Processing Record 28 of Set 13 | bulgan
# Processing Record 29 of Set 13 | kankon
# Processing Record 30 of Set 13 | yumen
# Processing Record 31 of Set 13 | matara
# Processing Record 32 of Set 13 | amurrio
# Processing Record 33 of Set 13 | tooele
# Processing Record 34 of Set 13 | ahipara
# Processing Record 35 of Set 13 | kristiansund
# Processing Record 36 of Set 13 | fort-shevchenko
# Processing Record 37 of Set 13 | novovarshavka
# Processing Record 38 of Set 13 | narrabri
# Processing Record 39 of Set 13 | benghazi
# Processing Record 40 of Set 13 | mangan
# Processing Record 41 of Set 13 | komsomolskiy
# Processing Record 42 of Set 13 | springbok
# Processing Record 43 of Set 13 | araouane
# Processing Record 44 of Set 13 | formosa
# Processing Record 45 of Set 13 | hualmay
# Processing Record 46 of Set 13 | alzamay
# Processing Record 47 of Set 13 | marzuq
# Processing Record 48 of Set 13 | dzhebariki-khaya
# Processing Record 49 of Set 13 | laredo
# Processing Record 50 of Set 13 | san juan del sur
# Processing Record 1 of Set 14 | mangai
# Processing Record 2 of Set 14 | paris
# Processing Record 3 of Set 14 | vestmannaeyjar
# Processing Record 4 of Set 14 | paamiut
# Processing Record 5 of Set 14 | coquimbo
# Processing Record 6 of Set 14 | raga
# Processing Record 7 of Set 14 | igrim
# Processing Record 8 of Set 14 | hobyo
# Processing Record 9 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 14 | atasu
# Processing Record 11 of Set 14 | nioro
# Processing Record 12 of Set 14 | lisakovsk
# Processing Record 13 of Set 14 | maldonado
# Processing Record 14 of Set 14 | khanpur
# Processing Record 15 of Set 14 | quatre cocos
# Processing Record 16 of Set 14 | point pedro
# Processing Record 17 of Set 14 | chongwe
# Processing Record 18 of Set 14 | uyar
# Processing Record 19 of Set 14 | nelson bay
# Processing Record 20 of Set 14 | morondava
# Processing Record 21 of Set 14 | atar
# Processing Record 22 of Set 14 | rodrigues alves
# Processing Record 23 of Set 14 | ciudad bolivar
# Processing Record 24 of Set 14 | kyra
# Processing Record 25 of Set 14 | kinkala
# Processing Record 26 of Set 14 | bastia
# Processing Record 27 of Set 14 | moron
# Processing Record 28 of Set 14 | hadejia
# Processing Record 29 of Set 14 | villa union
# Processing Record 30 of Set 14 | weihai
# Processing Record 31 of Set 14 | uyuni
# Processing Record 32 of Set 14 | saint anthony
# Processing Record 33 of Set 14 | dinar
# Processing Record 34 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 36 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 14 | kamakhyanagar
# Processing Record 38 of Set 14 | slonim
# Processing Record 39 of Set 14 | iqaluit
# Processing Record 40 of Set 14 | bartica
# Processing Record 41 of Set 14 | batticaloa
# Processing Record 42 of Set 14 | albania
# Processing Record 43 of Set 14 | zacapu
# Processing Record 44 of Set 14 | kenai
# Processing Record 45 of Set 14 | santa fe
# Processing Record 46 of Set 14 | bardsir
# Processing Record 47 of Set 14 | corinto
# Processing Record 48 of Set 14 | san pedro de macoris
# Processing Record 49 of Set 14 | requena
# Processing Record 50 of Set 14 | san pelayo
# Processing Record 1 of Set 15 | turukhansk
# Processing Record 2 of Set 15 | puerto madero
# Processing Record 3 of Set 15 | nuuk
# Processing Record 4 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 15 | sinazongwe
# Processing Record 6 of Set 15 | yarim
# Processing Record 7 of Set 15 | pakaur
# Processing Record 8 of Set 15 | rehoboth
# Processing Record 9 of Set 15 | ahar
# Processing Record 10 of Set 15 | maarianhamina
# Processing Record 11 of Set 15 | gold coast
# Processing Record 12 of Set 15 | pangnirtung
# Processing Record 13 of Set 15 | champerico
# Processing Record 14 of Set 15 | sechura
# Processing Record 15 of Set 15 | sidney
# Processing Record 16 of Set 15 | saint-augustin
# Processing Record 17 of Set 15 | port arthur
# Processing Record 18 of Set 15 | christchurch
# Processing Record 19 of Set 15 | usinsk
# Processing Record 20 of Set 15 | saint-joseph
# Processing Record 21 of Set 15 | umm lajj
# Processing Record 22 of Set 15 | antalaha
# Processing Record 23 of Set 15 | glendive
# Processing Record 24 of Set 15 | ojinaga
# Processing Record 25 of Set 15 | joshimath
# Processing Record 26 of Set 15 | kudymkar
# Processing Record 27 of Set 15 | huron
# Processing Record 28 of Set 15 | aasiaat
# Processing Record 29 of Set 15 | ostersund
# Processing Record 30 of Set 15 | sabzevar
# Processing Record 31 of Set 15 | ziarat
# Processing Record 32 of Set 15 | dongzhen
# Processing Record 33 of Set 15 | amahai
# Processing Record 34 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 15 | arman
# Processing Record 36 of Set 15 | wewak
# Processing Record 37 of Set 15 | laguna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany  42.6001  -73.9662     54.57        45         100
# 1    Puerto Ayora  -0.7393  -90.3518     76.96        92          63
# 2        Chingola -12.5290   27.8838     73.38        33          36
# 3       Jamestown  42.0970  -79.2353     57.06        39           0
# 4            Lasa  46.6166   10.7002     56.28        66          19
# 5         Mataura -46.1927  168.8643     58.21        93          70
# 6       Alyangula -13.8483  136.4192     82.65        71          15
# 7       Geraldton -28.7667  114.6000     64.81        82          75
# 8  Port Elizabeth -33.9180   25.5701     63.10        72         100
# 9         Ushuaia -54.8000  -68.3000     46.02        65          75
#
#    Wind Speed Country Current Description
# 0        1.90      US     overcast clouds
# 1       10.00      EC       broken clouds
# 2        4.92      ZM    scattered clouds
# 3        6.91      US           clear sky
# 4        2.26      IT          few clouds
# 5        2.73      NZ       broken clouds
# 6        6.51      AU          few clouds
# 7       14.97      AU       broken clouds
# 8       18.41      ZA     overcast clouds
# 9       33.38      AR       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001 -73.9662     54.57        45         100
# 1  Puerto Ayora      EC  -0.7393 -90.3518     76.96        92          63
# 2      Chingola      ZM -12.5290  27.8838     73.38        33          36
# 3     Jamestown      US  42.0970 -79.2353     57.06        39           0
# 4          Lasa      IT  46.6166  10.7002     56.28        66          19
#
#    Wind Speed Current Description
# 0        1.90     overcast clouds
# 1       10.00       broken clouds
# 2        4.92    scattered clouds
# 3        6.91           clear sky
# 4        2.26          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
